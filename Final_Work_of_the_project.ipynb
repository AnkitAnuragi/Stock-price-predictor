# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras

# %%
data_ours=pd.read_csv("data_ours.csv")

# %%
data_ours.head()
# Out:
#    Unnamed: 0 phase vacancy chiral_orientation  Strain_rate   Strain  \
# 0           0     h    1v2s           Armchair  10000000000  0.00035
# 1           1     h    1v2s           Armchair  10000000000  0.00095
# 2           2     h    1v2s           Armchair  10000000000  0.00155
# 3           3     h    1v2s           Armchair  10000000000  0.00215
# 4           4     h    1v2s           Armchair  10000000000  0.00275
#
#      Stress  molecular_mass crack_length  temperature  % ionic character
# 0  0.054708          115.08           no          300          16.752729
# 1  0.124270          115.08           no          300          16.752729
# 2  0.192165          115.08           no          300          16.752729
# 3  0.251728          115.08           no          300          16.752729
# 4  0.355276          115.08           no          300          16.752729

# %%
data_bang=pd.read_csv("data_bang.csv")

# %%
data_bang.head()
# Out:
#    Unnamed: 0  Strain Direction  Crack length  Temperature    Stress phase  \
# 0           0   0.000  Armchair             0          100  0.000000     h
# 1           1   0.001  Armchair             0          100  0.098407     h
# 2           2   0.002  Armchair             0          100  0.191496     h
# 3           3   0.003  Armchair             0          100  0.285939     h
# 4           4   0.004  Armchair             0          100  0.394138     h
#
#    molecular_mass vacancy  Strain_rate  %ionic character
# 0          160.07      no   1000000000          5.343447
# 1          160.07      no   1000000000          5.343447
# 2          160.07      no   1000000000          5.343447
# 3          160.07      no   1000000000          5.343447
# 4          160.07      no   1000000000          5.343447

# %%
column=["phase","vacancy","crack_length","molecular_mass","chiral_orientation","% ionic character","strain_rate","temperature","strain","stress"]

# %%
data_ours.head()
# Out:
#    Unnamed: 0 phase vacancy chiral_orientation  Strain_rate   Strain  \
# 0           0     h    1v2s           Armchair  10000000000  0.00035
# 1           1     h    1v2s           Armchair  10000000000  0.00095
# 2           2     h    1v2s           Armchair  10000000000  0.00155
# 3           3     h    1v2s           Armchair  10000000000  0.00215
# 4           4     h    1v2s           Armchair  10000000000  0.00275
#
#      Stress  molecular_mass crack_length  temperature  % ionic character
# 0  0.054708          115.08           no          300          16.752729
# 1  0.124270          115.08           no          300          16.752729
# 2  0.192165          115.08           no          300          16.752729
# 3  0.251728          115.08           no          300          16.752729
# 4  0.355276          115.08           no          300          16.752729

# %%
data_ours.rename(columns={"phase":column[0],
                      "vacancy":column[1],
                      "crack_length":column[2],
                      "molecular_mass":column[3],
                      "chiral_orientation":column[4],
                      "% ionic character":column[5],
                      "Strain_rate":column[6],
                      "temperature":column[7],
                      "Strain":column[8],
                      "Stress":column[9]
                    },inplace=True)

# %%
data_bang.head()
# Out:
#    Unnamed: 0  Strain Direction  Crack length  Temperature    Stress phase  \
# 0           0   0.000  Armchair             0          100  0.000000     h
# 1           1   0.001  Armchair             0          100  0.098407     h
# 2           2   0.002  Armchair             0          100  0.191496     h
# 3           3   0.003  Armchair             0          100  0.285939     h
# 4           4   0.004  Armchair             0          100  0.394138     h
#
#    molecular_mass vacancy  Strain_rate  %ionic character
# 0          160.07      no   1000000000          5.343447
# 1          160.07      no   1000000000          5.343447
# 2          160.07      no   1000000000          5.343447
# 3          160.07      no   1000000000          5.343447
# 4          160.07      no   1000000000          5.343447

# %%
data_bang.rename(columns={"phase":column[0],
                      "vacancy":column[1],
                      "Crack length":column[2],
                      "molecular_mass":column[3],
                      "Direction":column[4],
                      "%ionic character":column[5],
                      "Strain_rate":column[6],
                      "Temperature":column[7],
                      "Strain":column[8],
                      "Stress":column[9]
                    },inplace=True)

# %%
data_bang.head()
# Out:
#    Unnamed: 0  strain chiral_orientation  crack_length  temperature    stress  \
# 0           0   0.000           Armchair             0          100  0.000000
# 1           1   0.001           Armchair             0          100  0.098407
# 2           2   0.002           Armchair             0          100  0.191496
# 3           3   0.003           Armchair             0          100  0.285939
# 4           4   0.004           Armchair             0          100  0.394138
#
#   phase  molecular_mass vacancy  strain_rate  % ionic character
# 0     h          160.07      no   1000000000           5.343447
# 1     h          160.07      no   1000000000           5.343447
# 2     h          160.07      no   1000000000           5.343447
# 3     h          160.07      no   1000000000           5.343447
# 4     h          160.07      no   1000000000           5.343447

# %%
temp1.rename(columns={"phase":column[0],
                      "vacancy":column[1],
                      "Crack length":column[2],
                      "Molecular_mass":column[3],
                      "Direction":column[4],
                      "% ionic character":column[5],
                      "Strain_rate":column[6],
                      "Temperature":column[7],
                      "Strain":column[8],
                      "Stress":column[9]
                    },inplace=True)

# %%
data_ours.to_csv("data_ours_final.csv")

# %%
data_bang
